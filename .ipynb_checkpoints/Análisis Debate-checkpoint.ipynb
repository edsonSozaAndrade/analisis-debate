# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import json
import plotly.express as px

import re
import nltk
from nltk.corpus import stopwords
from collections import Counter,defaultdict

from textblob import TextBlob
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASrock\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Cargar JSON
with open('data/diarization_transcript_renamed.json', 'r', encoding='utf-8') as f:
    diarization_data = json.load(f)

# Convertir a DataFrame
df = pd.DataFrame(diarization_data)
# Filtrar speakers innecesarios
speakers_excluir = ['Cecilia','Juan Carlos','Voz en Off','Marilin Morales','UNKNOWN',
                    'SPEAKER_09','Yeyo Vera','SPEAKER_05','SPEAKER_11','SPEAKER_02','SPEAKER_12']
df_filtrado = df[~df['speaker'].isin(speakers_excluir)].copy()

# %%
# Crear el summary por candidato
df_filtrado['duration'] = df_filtrado['end'] - df_filtrado['start']
summary = df_filtrado.groupby('speaker').agg({
    'duration': 'sum',
    'text': lambda x: ' '.join(x)
}).reset_index()

# Contar palabras por locutor
summary['word_count'] = summary['text'].apply(lambda x: len(x.split()))
summary.sort_values('duration', ascending=False)
# Out:
#                       speaker  duration  \
# 0        Eduardo del Castillo   1632.48
# 1    Jhonny Fernández Saucedo   1629.14
# 3         Manfred Reyes Villa   1476.40
# 4         Samuel Doria Medina   1423.20
# 2  Jorge Tuto Quiroga Ramírez   1352.24
#
#                                                 text  word_count
# 0   Muy buenas noches  saludar a todas y cada una...        4705
# 1   Buenas noches a todos los hermanos  que están...        4324
# 3   Manfred Reyes Sevilla.  Buenas noches.  Buena...        3944
# 4   Muy buenas noches.  Estoy muy contento de est...        3366
# 2   porque de Tuto Quiroga, adelante Tuto.  Buena...        3293

# %%
# Función de limpieza de caracteres
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-záéíóúñü\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()
    
# Extraer palabras comunes
def get_most_common_words(text, n=5):
    words = text.split()
    words = [w for w in words if w not in stop_words and len(w) > 4]
    counter = Counter(words)
    return counter.most_common(n)
    
# Analisis Sentimiento
def analyze_sentiment(text):
    result = sentiment_analyzer(text)[0]
    label = result['label']
    score = int(label[0])
    return score
    
# Analisis de Sentimientos //Textblob
def sentiment_analysis(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity  # valor entre -1 y 1

# Analisis de Sentimientos por chunk
def analyze_sentiment(text, chunk_size=100):
    words = text.split()
    chunks = [' '.join(words[i:i+chunk_size]) for i in range(0, len(words), chunk_size)]

    scores = []
    for chunk in chunks:
        try:
            result = sentiment_analyzer(chunk)[0]
            score = int(result['label'][0])
            scores.append(score)
        except Exception as e:
            print(f"Error con fragmento: {chunk[:60]}... -> {e}")
            continue

    if scores:
        return round(sum(scores) / len(scores), 2) 
    else:
        return None
        
# Emoji generación
def sentiment_emoji(score):
    if score <= 1.5:
        return '😡'
    elif score <= 2.5:
        return '😕'
    elif score <= 3.5:
        return '😐'
    elif score <= 4.5:
        return '🙂'
    else:
        return '😄'

# %%
#Limpiar texto
summary['clean_text'] = summary['text'].apply(clean_text)
stop_words = set(stopwords.words('spanish'))
rows = []

# Recorrer cada locutor y obtener sus palabras más comunes
for _, row in summary.iterrows():
    speaker = row['speaker']
    text = row['clean_text']
    common_words = get_most_common_words(text, n=5)

    for word, count in common_words:
        rows.append({'speaker': speaker, 'word': word, 'count': count})

# Convertir a DataFrame
df_palabras_comunes = pd.DataFrame(rows)

# %%
#Grafica palabras comunes
pivot_df = df_palabras_comunes.pivot_table(
    index='word',
    columns='speaker',
    values='count',
    aggfunc='sum',
    fill_value=0
)

pivot_df = pivot_df.astype(int)

plt.figure(figsize=(14, 8))
sns.heatmap(pivot_df, annot=True, fmt='d', cmap='Blues')
plt.title("Palabras más comunes por candidato")
plt.tight_layout()
plt.show()

# %%
#Nube de Palabras
for i, row in summary.iterrows():
    # Filtrar palabras con al menos 4 caracteres
    palabras_filtradas = ' '.join([w for w in row['clean_text'].split() if len(w) >= 5])
    wc = WordCloud(width=800, height=400, background_color='white').generate(palabras_filtradas)
    plt.figure(figsize=(10,5))
    plt.title(f'Nube de palabras - {row["speaker"]}')
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
#Analisis de Sentimiento TextBlob
summary['sentiment'] = summary['clean_text'].apply(sentiment_analysis)

#Grafica Sentimientos
sns.barplot(data=summary, x='sentiment', y='speaker', hue='speaker', palette='coolwarm', dodge=False)
plt.title('Análisis de sentimiento por locutor')
#plt.savefig('graphs/grafico_sentimiento_locutor.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
# Crear pipeline para análisis de sentimiento
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="nlptown/bert-base-multilingual-uncased-sentiment"
)
summary.head()
# Out:
# Device set to use cpu
#                       speaker  duration  \
# 0        Eduardo del Castillo   1632.48
# 1    Jhonny Fernández Saucedo   1629.14
# 2  Jorge Tuto Quiroga Ramírez   1352.24
# 3         Manfred Reyes Villa   1476.40
# 4         Samuel Doria Medina   1423.20
#
#                                                 text  word_count  \
# 0   Muy buenas noches  saludar a todas y cada una...        4705
# 1   Buenas noches a todos los hermanos  que están...        4324
# 2   porque de Tuto Quiroga, adelante Tuto.  Buena...        3293
# 3   Manfred Reyes Sevilla.  Buenas noches.  Buena...        3944
# 4   Muy buenas noches.  Estoy muy contento de est...        3366
#
#                                           clean_text  sentiment
# 0  muy buenas noches saludar a todas y cada una d...   0.016667
# 1  buenas noches a todos los hermanos que están e...  -0.040000
# 2  porque de tuto quiroga adelante tuto buenas no...   0.006667
# ...

# %%
# Aplicar analisis de sentimiento por chunks
summary['sentiment_score'] = summary['clean_text'].apply(analyze_sentiment)

# %%
# Imprimir Summary de sentimientos
print(summary[['speaker', 'sentiment_score']])

# Añadir el emoji al df
summary['emoji'] = summary['sentiment_score'].apply(sentiment_emoji)
summary[['speaker', 'sentiment_score', 'emoji']]
# Out:
#                       speaker  sentiment_score
# 0        Eduardo del Castillo             2.43
# 1    Jhonny Fernández Saucedo             2.14
# 2  Jorge Tuto Quiroga Ramírez             2.30
# 3         Manfred Reyes Villa             2.05
# 4         Samuel Doria Medina             2.15
#                       speaker  sentiment_score emoji
# 0        Eduardo del Castillo             2.43     😕
# 1    Jhonny Fernández Saucedo             2.14     😕
# 2  Jorge Tuto Quiroga Ramírez             2.30     😕
# 3         Manfred Reyes Villa             2.05     😕
# 4         Samuel Doria Medina             2.15     😕

# %%
# Ordenar por sentimiento descendente (opcional)
summary_sorted = summary.sort_values(by='sentiment_score', ascending=False)

# Grafica por promedio sentimiento
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=summary_sorted,
    x='sentiment_score',
    y='speaker',
    hue='speaker',        # Se requiere para usar palette
    palette='coolwarm',
    dodge=False,
    legend=False          # Opcional: oculta la leyenda
)
plt.title("Puntaje promedio de sentimiento por candidato")
#plt.savefig("graphs/sentimiento_promedio_candidatos.png", bbox_inches='tight', dpi=300)
plt.show()

# %%
# Creación de fragmentos de 60 segundos para aplicar el analisis de sentimientos
df_fragments = df_filtrado.copy()
df_fragments['clean_text'] = df_fragments['text'].apply(clean_text)
df_fragments['sentiment_score'] = df_fragments['clean_text'].apply(analyze_sentiment)
df_fragments['minute'] = (df_fragments['start'] // 60).astype(int)
df_fragments.head()
# Out:
#                       speaker  start    end  \
# 207  Jhonny Fernández Saucedo  458.6  460.6
# 208  Jhonny Fernández Saucedo  460.6  462.6
# 209  Jhonny Fernández Saucedo  462.6  464.6
# 210  Jhonny Fernández Saucedo  464.6  466.6
# 211  Jhonny Fernández Saucedo  466.6  468.6
#
#                                            text  duration  \
# 207          Buenas noches a todos los hermanos       2.0
# 208   que están en todo el territorio nacional.       2.0
# 209                 Hoy es un día muy especial.       2.0
# 210           Porque hoy nos dan la oportunidad       2.0
# 211                       de decirles a ustedes       2.0
#
#                                    clean_text  sentiment_score  minute
# 207        buenas noches a todos los hermanos              5.0       7
# 208  que están en todo el territorio nacional              5.0       7
# 209                hoy es un día muy especial              5.0       7
# ...

# %%
# Agrupar por candidato en una línea de tiempo
df_timeline = df_fragments.groupby(['speaker', 'minute'])['sentiment_score'].mean().reset_index()

# %%
speakers = df_timeline['speaker'].unique()

# Crear un gráfico por locutor
color_map = {
    "Eduardo del Castillo": "#1546ea",
    "Jhonny Fernández Saucedo": "#17e4ee",
    "Jorge Tuto Quiroga Ramírez": "#f33e0e",
    "Manfred Reyes Villa": "#6f0ff0",
    "Samuel Doria Medina": "#f8f104"
    # Agrega más si hay más candidatos
}
for speaker in speakers:
    df_speaker = df_timeline[df_timeline['speaker'] == speaker]
    color = color_map.get(speaker, '#333333')
    fig = px.line(
        df_speaker,
        x='minute',
        y='sentiment_score',
        line_shape='spline',
        markers=True,
        labels={
            'minute': 'Minuto del debate',
            'sentiment_score': 'Sentimiento'
        },
        title=f'📊 Evolución del Sentimiento - {speaker}',
        color_discrete_sequence=[color]
    )

    fig.update_yaxes(range=[1, 5], title='Sentimiento (1=Negativo, 5=Positivo)')
    fig.update_traces(line=dict(width=2))
    fig.update_layout(
        showlegend=False,
        template='plotly_white',
        margin=dict(t=60, b=40, l=40, r=40)
    )

    # Mostrar (opcional)
    fig.show()

    # Guardar como HTML interactivo
    filename_html = f"sentimiento_{speaker.replace(' ', '_')}.html"
    fig.write_html(filename_html)
